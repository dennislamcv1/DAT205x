# %% [markdown]
# ### Data Description

# %% [markdown]
# Lastly, Lucy wants to have more information about the customer demographics in addition to the already available age and gender. Since your data (download file here) has Customer ID for each row, you can "connect" these rows with your customer demographics database.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv("Lab8.csv")

# %%
df
# Out:
#              Date      Month  Year  Customer ID  Customer Age  \
# 0       22/7/2013       July  2013        11000            31
# 1       22/7/2015       July  2015        11000            31
# 2       30/9/2013  September  2013        11000            31
# 3       30/9/2015  September  2015        11000            31
# 4       28/1/2013    January  2013        11000            31
# ...           ...        ...   ...          ...           ...
# 113031   5/4/2015      April  2015        29483            38
# 113032  30/8/2013     August  2013        29483            38
# 113033  30/8/2015     August  2015        29483            38
# 113034   7/2/2014   February  2014        29483            38
# 113035   7/2/2016   February  2016        29483            38
#
#                    Age Group Customer Gender    Country           State  \
# 0       Young Adults (25-34)               M  Australia      Queensland
# 1       Young Adults (25-34)               M  Australia      Queensland
# ...

# %%
df.drop(['Date','Month','Year'],axis=1,inplace=True)

# %%
df
# Out:
#         Customer ID  Customer Age             Age Group Customer Gender  \
# 0             11000            31  Young Adults (25-34)               M
# 1             11000            31  Young Adults (25-34)               M
# 2             11000            31  Young Adults (25-34)               M
# 3             11000            31  Young Adults (25-34)               M
# 4             11000            31  Young Adults (25-34)               M
# ...             ...           ...                   ...             ...
# 113031        29483            38        Adults (35-64)               M
# 113032        29483            38        Adults (35-64)               M
# 113033        29483            38        Adults (35-64)               M
# 113034        29483            38        Adults (35-64)               M
# 113035        29483            38        Adults (35-64)               M
#
#           Country           State Product Category    Sub Category  \
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Customer Age', 'Age Group', 'Customer Gender',
#        'Country', 'State', 'Product Category', 'Sub Category', 'Product',
#        'Frame Size', 'Order Quantity', 'Unit Cost', 'Unit Price', 'Cost',
#        'Revenue', 'Profit'],
#       dtype='object')

# %%
df2 = pd.read_csv("Customer_demographics.csv")

# %%
df2
# Out:
#           ID  Customer ID MaritalStatus  YearlyIncome  TotalChildren  \
# 0          1        11000             M         90000              2
# 1          2        11001             S         60000              3
# 2          3        11002             M         60000              3
# 3          4        11003             S         70000              0
# 4          5        11004             S         80000              5
# ...      ...          ...           ...           ...            ...
# 18479  18480        29479             M         30000              1
# 18480  18481        29480             S         30000              3
# 18481  18482        29481             S         30000              3
# 18482  18483        29482             M         30000              3
# 18483  18484        29483             M         30000              0
#
#       EnglishEducation  HouseOwnerFlag
# 0            Bachelors            True
# 1            Bachelors           False
# ...

# %%
del df2['ID']

# %%
df2
# Out:
#        Customer ID MaritalStatus  YearlyIncome  TotalChildren  \
# 0            11000             M         90000              2
# 1            11001             S         60000              3
# 2            11002             M         60000              3
# 3            11003             S         70000              0
# 4            11004             S         80000              5
# ...            ...           ...           ...            ...
# 18479        29479             M         30000              1
# 18480        29480             S         30000              3
# 18481        29481             S         30000              3
# 18482        29482             M         30000              3
# 18483        29483             M         30000              0
#
#       EnglishEducation  HouseOwnerFlag
# 0            Bachelors            True
# 1            Bachelors           False
# 2            Bachelors            True
# 3            Bachelors           False
# ...

# %%
df3 = pd.merge(left=df, right=df2, how='inner', left_on='Customer ID',right_on='Customer ID')

# %%
df3
# Out:
#         Customer ID  Customer Age             Age Group Customer Gender  \
# 0             11000            31  Young Adults (25-34)               M
# 1             11000            31  Young Adults (25-34)               M
# 2             11000            31  Young Adults (25-34)               M
# 3             11000            31  Young Adults (25-34)               M
# 4             11000            31  Young Adults (25-34)               M
# ...             ...           ...                   ...             ...
# 113031        29483            38        Adults (35-64)               M
# 113032        29483            38        Adults (35-64)               M
# 113033        29483            38        Adults (35-64)               M
# 113034        29483            38        Adults (35-64)               M
# 113035        29483            38        Adults (35-64)               M
#
#           Country           State Product Category    Sub Category  \
# ...

# %% [markdown]
# Create a new pivot table from the SalesTable then click More tables.

# %% [markdown]
# Now, add the MaritalStatus and TotalChildren fields from the Customer_demographic table as Rows and Order Quantity from the SalesTable as Values. In addition, add the Product Category as filters.

# %%
df3.columns
# Out:
# Index(['Customer ID', 'Customer Age', 'Age Group', 'Customer Gender',
#        'Country', 'State', 'Product Category', 'Sub Category', 'Product',
#        'Frame Size', 'Order Quantity', 'Unit Cost', 'Unit Price', 'Cost',
#        'Revenue', 'Profit', 'MaritalStatus', 'YearlyIncome', 'TotalChildren',
#        'EnglishEducation', 'HouseOwnerFlag'],
#       dtype='object')

# %%
df4 = df3.pivot_table(values='Order Quantity',index=['MaritalStatus','TotalChildren'],
                      aggfunc=len,columns='Product Category',margins=True)

# %%
df4
# Out:
# Product Category             Accessories  Bikes  Clothing     All
# MaritalStatus TotalChildren
# M             0                     6494   2706      1488   10688
#               1                     8984   3886      2216   15086
#               2                     8842   2868      2216   13926
#               3                     4588   1726      1182    7496
#               4                     6242   1442      1636    9320
#               5                     3816    854       952    5622
# S             0                    12828   4694      2938   20460
#               1                     3640   1936       830    6406
#               2                     5638   2824      1448    9910
#               3                     3366   1324       840    5530
#               4                     3776   1128       770    5674
#               5                     1906    594       418    2918
# All                                70120  25982     16934  113036

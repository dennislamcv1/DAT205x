# %% [markdown]
# ### Data Description

# %% [markdown]
# While your first attempt to show the company's performance to Lucy was not bad, clearly she has a lot more requirements than what you provided. She wants to know more about the year over year sales, sliced into different categories, sub-categories, and countries. She also wants to see additional information such as customer demographics.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv("Lab2.csv",parse_dates=['Date'])

# %%
df
# Out:
#              Date  Year  Customer ID  Customer Age Customer Gender  \
# 0      2013-11-26  2013        11019            19               M
# 1      2015-11-26  2015        11019            19               M
# 2      2014-03-23  2014        11039            49               M
# 3      2016-03-23  2016        11039            49               M
# 4      2014-05-15  2014        11046            47               F
# ...           ...   ...          ...           ...             ...
# 113031 2016-12-04  2016        29443            41               M
# 113032 2014-02-04  2014        29462            18               M
# 113033 2016-02-04  2016        29462            18               M
# 113034 2014-04-03  2014        29472            37               F
# 113035 2016-04-03  2016        29472            37               F
#
#                Country             State Product Category Sub Category  \
# 0               Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Year              113036 non-null  int64
#  2   Customer ID       113036 non-null  int64
#  3   Customer Age      113036 non-null  int64
#  4   Customer Gender   113036 non-null  object
#  5   Country           113036 non-null  object
#  6   State             113036 non-null  object
#  7   Product Category  113036 non-null  object
#  8   Sub Category      113036 non-null  object
#  9   Product           113036 non-null  object
#  10  Order Quantity    113036 non-null  int64
#  11  Unit Cost         113036 non-null  int64
#  12  Unit Price        113036 non-null  int64
#  13  Cost              113036 non-null  int64
#  14  Revenue           113036 non-null  int64
# dtypes: datetime64[ns](1), int64(8), object(6)
# ...

# %%
df['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %%
usa = df[df['Country'] == 'United States']

# %%
usa
# Out:
#              Date  Year  Customer ID  Customer Age Customer Gender  \
# 22     2014-03-27  2014        11196            51               M
# 23     2016-03-27  2016        11196            51               M
# 34     2013-07-19  2013        11259            32               F
# 35     2015-07-19  2015        11259            32               F
# 38     2013-07-13  2013        11295            43               F
# ...           ...   ...          ...           ...             ...
# 113021 2015-02-10  2015        29238            34               M
# 113022 2014-03-20  2014        29238            34               M
# 113023 2016-03-20  2016        29238            34               M
# 113024 2014-03-04  2014        29238            34               M
# 113025 2016-03-04  2016        29238            34               M
#
#               Country       State Product Category Sub Category  \
# 22      United States      Oregon      Accessories   Bike Racks
# ...

# %%
usa['Revenue'].sum()
# Out:
# 27975547

# %%
df
# Out:
#              Date  Year  Customer ID  Customer Age Customer Gender  \
# 0      2013-11-26  2013        11019            19               M
# 1      2015-11-26  2015        11019            19               M
# 2      2014-03-23  2014        11039            49               M
# 3      2016-03-23  2016        11039            49               M
# 4      2014-05-15  2014        11046            47               F
# ...           ...   ...          ...           ...             ...
# 113031 2016-12-04  2016        29443            41               M
# 113032 2014-02-04  2014        29462            18               M
# 113033 2016-02-04  2016        29462            18               M
# 113034 2014-04-03  2014        29472            37               F
# 113035 2016-04-03  2016        29472            37               F
#
#                Country             State Product Category Sub Category  \
# 0               Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
df['Month'] = df['Date'].dt.month

# %%
df
# Out:
#              Date  Year  Customer ID  Customer Age Customer Gender  \
# 0      2013-11-26  2013        11019            19               M
# 1      2015-11-26  2015        11019            19               M
# 2      2014-03-23  2014        11039            49               M
# 3      2016-03-23  2016        11039            49               M
# 4      2014-05-15  2014        11046            47               F
# ...           ...   ...          ...           ...             ...
# 113031 2016-12-04  2016        29443            41               M
# 113032 2014-02-04  2014        29462            18               M
# 113033 2016-02-04  2016        29462            18               M
# 113034 2014-04-03  2014        29472            37               F
# 113035 2016-04-03  2016        29472            37               F
#
#                Country             State Product Category Sub Category  \
# 0               Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
df['Customer Age'].unique()
# Out:
# array([19, 49, 47, 35, 32, 34, 29, 51, 48, 43, 61, 57, 38, 52, 24, 23, 26,
#        54, 46, 41, 33, 42, 45, 53, 21, 22, 67, 31, 37, 87, 25, 40, 44, 55,
#        50, 59, 17, 27, 28, 36, 56, 58, 30, 18, 62, 39, 64, 63, 20, 60, 84,
#        68, 65, 73, 69, 66, 75, 76, 78, 71, 72, 82, 86, 77, 74, 85, 81, 80,
#        70, 79], dtype=int64)

# %%
bins=[0,24,34,64,100]

# %%
agegroup = pd.cut(x=df['Customer Age'],bins=bins,labels=['Youth (<25)','Young Adults (25-34)','Adults (35-64)',
                                                     'Seniors (>64)'],right=False)

# %%
agegroup
# Out:
# 0            Youth (<25)
# 1            Youth (<25)
# 2         Adults (35-64)
# 3         Adults (35-64)
# 4         Adults (35-64)
#                ...
# 113031    Adults (35-64)
# 113032       Youth (<25)
# 113033       Youth (<25)
# 113034    Adults (35-64)
# 113035    Adults (35-64)
# Name: Customer Age, Length: 113036, dtype: category
# Categories (4, object): [Youth (<25) < Young Adults (25-34) < Adults (35-64) < Seniors (>64)]

# %%
df['Product Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product Category, dtype: int64

# %%
bikes = df[df['Product Category'] == 'Bikes']

# %%
bikes
# Out:
#              Date  Year  Customer ID  Customer Age Customer Gender  \
# 49304  2013-01-28  2013        11000            31               M
# 49305  2015-01-28  2015        11000            31               M
# 49306  2013-07-22  2013        11000            31               M
# 49307  2015-07-22  2015        11000            31               M
# 49308  2013-12-25  2013        11000            31               M
# ...           ...   ...          ...           ...             ...
# 112067 2016-01-18  2016        29480            37               F
# 112068 2014-02-27  2014        29480            37               F
# 112069 2016-02-27  2016        29480            37               F
# 112070 2014-06-13  2014        29480            37               F
# 112071 2016-06-13  2016        29480            37               F
#
#                Country       State Product Category    Sub Category  \
# 49304        Australia  Queensland            Bikes  Mountain Bikes
# ...

# %%
bikes['Product'].value_counts()
# Out:
# Mountain-200 Black, 38     1208
# Mountain-200 Silver, 38    1106
# Mountain-200 Silver, 42    1054
# Mountain-200 Black, 46      992
# Mountain-200 Black, 42      926
#                            ...
# Touring-3000 Blue, 50        58
# Mountain-100 Silver, 42      54
# Mountain-500 Silver, 48      40
# Road-650 Red, 52             32
# Mountain-500 Black, 52       22
# Name: Product, Length: 88, dtype: int64

# %%
df
# Out:
#              Date  Year  Customer ID  Customer Age Customer Gender  \
# 0      2013-11-26  2013        11019            19               M
# 1      2015-11-26  2015        11019            19               M
# 2      2014-03-23  2014        11039            49               M
# 3      2016-03-23  2016        11039            49               M
# 4      2014-05-15  2014        11046            47               F
# ...           ...   ...          ...           ...             ...
# 113031 2016-12-04  2016        29443            41               M
# 113032 2014-02-04  2014        29462            18               M
# 113033 2016-02-04  2016        29462            18               M
# 113034 2014-04-03  2014        29472            37               F
# 113035 2016-04-03  2016        29472            37               F
#
#                Country             State Product Category Sub Category  \
# 0               Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
df['Profit'] = df['Revenue']-df['Cost']

# %%
df
# Out:
#              Date  Year  Customer ID  Customer Age Customer Gender  \
# 0      2013-11-26  2013        11019            19               M
# 1      2015-11-26  2015        11019            19               M
# 2      2014-03-23  2014        11039            49               M
# 3      2016-03-23  2016        11039            49               M
# 4      2014-05-15  2014        11046            47               F
# ...           ...   ...          ...           ...             ...
# 113031 2016-12-04  2016        29443            41               M
# 113032 2014-02-04  2014        29462            18               M
# 113033 2016-02-04  2016        29462            18               M
# 113034 2014-04-03  2014        29472            37               F
# 113035 2016-04-03  2016        29472            37               F
#
#                Country             State Product Category Sub Category  \
# 0               Canada  British Columbia      Accessories   Bike Racks
# ...

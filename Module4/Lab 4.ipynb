# %% [markdown]
# ### Data Description

# %% [markdown]
# So far everything has been well received by her. However, she would like to have easier ways to slice and dice the reports and charts herself.
#
# You sat down with Lucy, and come up with several different ways that Lucy could slice the data
#
#         Year
#         Country
#         Customer Gender
#         Age Group
#         Product Category
#         Sub Category
#         Frame size

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv("Lab4.csv")

# %%
df
# Out:
#              Date    Month  Year  CustomerID  CustomerAge  \
# 0        1/1/2011  January  2011       11455           23
# 1        1/1/2011  January  2011       12494           33
# 2        1/1/2011  January  2011       13148           17
# 3        1/1/2011  January  2011       16361           42
# 4        1/1/2011  January  2011       19413           39
# ...           ...      ...   ...         ...          ...
# 113031  31/7/2016     July  2016       27496           43
# 113032  31/7/2016     July  2016       27686           34
# 113033  31/7/2016     July  2016       27686           34
# 113034  31/7/2016     July  2016       13350           54
# 113035  31/7/2016     July  2016       13948           38
#
#                     AgeGroup CustomerGender        Country             State  \
# 0                Youth (<25)              M      Australia          Victoria
# 1       Young Adults (25-34)              F         France           Yveline
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Month', 'Year', 'CustomerID', 'CustomerAge', 'AgeGroup',
#        'CustomerGender', 'Country', 'State', 'ProductCategory', 'SubCategory',
#        'Product', 'FrameSize', 'OrderQuantity', 'UnitCost', 'UnitPrice',
#        'Cost', 'Revenue', 'Profit'],
#       dtype='object')

# %%
df = df[['Year','Country','CustomerGender','AgeGroup','ProductCategory','SubCategory', 'FrameSize','Revenue']]

# %%
df
# Out:
#         Year        Country CustomerGender              AgeGroup  \
# 0       2011      Australia              M           Youth (<25)
# 1       2011         France              F  Young Adults (25-34)
# 2       2011         Canada              M           Youth (<25)
# 3       2011  United_States              M        Adults (35-64)
# 4       2011  United_States              M        Adults (35-64)
# ...      ...            ...            ...                   ...
# 113031  2016      Australia              M        Adults (35-64)
# 113032  2016      Australia              M  Young Adults (25-34)
# 113033  2016      Australia              M  Young Adults (25-34)
# 113034  2016         Canada              M        Adults (35-64)
# 113035  2016  United_States              F        Adults (35-64)
#
#        ProductCategory      SubCategory  FrameSize  Revenue
# 0                Bikes   Mountain Bikes       46.0      NaN
# 1                Bikes       Road Bikes       48.0   5439.0
# ...

# %% [markdown]
# Create an additional pivot chart to show Sales by Country using Pie chart. Show percentages for each slice of the pie and connect the chart to all the slicers, except the Country slicer.

# %%
df.isnull().sum()
# Out:
# Year                   0
# Country                0
# CustomerGender         0
# AgeGroup               0
# ProductCategory        0
# SubCategory            0
# FrameSize          87054
# Revenue                1
# dtype: int64

# %%
df.fillna(0)
# Out:
#         Year        Country CustomerGender              AgeGroup  \
# 0       2011      Australia              M           Youth (<25)
# 1       2011         France              F  Young Adults (25-34)
# 2       2011         Canada              M           Youth (<25)
# 3       2011  United_States              M        Adults (35-64)
# 4       2011  United_States              M        Adults (35-64)
# ...      ...            ...            ...                   ...
# 113031  2016      Australia              M        Adults (35-64)
# 113032  2016      Australia              M  Young Adults (25-34)
# 113033  2016      Australia              M  Young Adults (25-34)
# 113034  2016         Canada              M        Adults (35-64)
# 113035  2016  United_States              F        Adults (35-64)
#
#        ProductCategory      SubCategory  FrameSize  Revenue
# 0                Bikes   Mountain Bikes       46.0      0.0
# 1                Bikes       Road Bikes       48.0   5439.0
# ...

# %%
df.isnull().sum()
# Out:
# Year                   0
# Country                0
# CustomerGender         0
# AgeGroup               0
# ProductCategory        0
# SubCategory            0
# FrameSize          87054
# Revenue                1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             113036 non-null  int64
#  1   Country          113036 non-null  object
#  2   CustomerGender   113036 non-null  object
#  3   AgeGroup         113036 non-null  object
#  4   ProductCategory  113036 non-null  object
#  5   SubCategory      113036 non-null  object
#  6   FrameSize        25982 non-null   float64
#  7   Revenue          113035 non-null  float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 6.9+ MB

# %%
df1 = pd.pivot_table(df, values='Revenue',index='Country')

# %%
df1
# Out:
#                    Revenue
# Country
# Australia       889.920451
# Canada          559.721964
# France          766.764139
# Germany         809.028293
# United_Kingdom  781.659031
# United_States   713.552696

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#           Country     Revenue
# 0       Australia  889.920451
# 1          Canada  559.721964
# 2          France  766.764139
# 3         Germany  809.028293
# 4  United_Kingdom  781.659031
# 5   United_States  713.552696

# %%
plt.figure(figsize=(10,10))
plt.pie(df1.Revenue,labels=df1.Country)
plt.show()

# %% [markdown]
# Create an additional pivot chart to show Sales by Category using a Pie chart. Show percentages for each slice of the pie and connect the chart to all the slicers, except the Category slicer.

# %%
df2 = pd.pivot_table(df, values='Revenue',index='ProductCategory')
df2
# Out:
#                      Revenue
# ProductCategory
# Accessories       215.601711
# Bikes            2377.903891
# Clothing          494.323964

# %%
df2.reset_index(inplace=True)
df2
# Out:
#   ProductCategory      Revenue
# 0     Accessories   215.601711
# 1           Bikes  2377.903891
# 2        Clothing   494.323964

# %%
plt.figure(figsize=(10,10))
plt.pie(df2.Revenue,labels=df2.ProductCategory)
plt.show()

# %% [markdown]
# Create an additional pivot chart to show Sales by Customer Gender using Pie chart. Show percentages for each slice of the pie and connect the chart to all the slicers, except the Customer Gender slicer.

# %%
df3 = pd.pivot_table(df, values='Revenue',index='CustomerGender')
df3
# Out:
#                    Revenue
# CustomerGender
# F               766.310924
# M               743.146165

# %%
df3.reset_index(inplace=True)
df3
# Out:
#   CustomerGender     Revenue
# 0              F  766.310924
# 1              M  743.146165

# %%
df3['Revenue'].sum()
# Out:
# 1509.4570884406344

# %%
df3['Percentage'] = (df3['Revenue']/df3['Revenue'].sum() * 100)

# %%
df3['Percentage'] = df3['Percentage'].round(2)

# %%
df3
# Out:
#   CustomerGender     Revenue  Percentage
# 0              F  766.310924       50.77
# 1              M  743.146165       49.23

# %%
plt.figure(figsize=(10,10))
plt.pie(df3.Revenue,labels=df3.CustomerGender)
plt.legend(df3.Percentage)
plt.show()

# %% [markdown]
# What about Customer Gender vs age group? Right now the Sales by Age Group chart does not differentiate by Gender. Modify this chart to be a Column chart. Show the Customer Gender side-by-side for each age group.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=df.AgeGroup,y=df.Revenue,hue=df.CustomerGender,ci=None);
